# %%
text = "I'm am Ali whats your name "
print(text.split())
print(re.split(r'\W+',text))
# Out:
# ["I'm", 'am', 'Ali', 'whats', 'your', 'name']
# ['I', 'm', 'am', 'Ali', 'whats', 'your', 'name', '']

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Tokenizing
doc = nlp(text)
print(doc)
for token in doc:
    print(token.text , end=' | ')
# Out:
# I'm am Ali whats your name
# I | 'm | am | Ali | what | s | your | name |

# %%
doc2 = nlp(u'Im from UK a $100 company NYC.')
for t in doc2:
    print(t)
# Out:
# I
# m
# from
# UK
# a
# $
# 100
# company
# NYC
# .

# %%
print(len(doc2))
print(len(doc2.vocab))
print(doc2[3:6]) # retrive tokens
# Out:
# 10
# 770
# UK a $

# %%
doc[0] = doc2[0] #We can't assign
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e8677112df55> in <module>
# ----> 1 doc[0] = doc2[0] #We can't assign
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %% [markdown]
# ## POS and dependency

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion . Apple is very sweet nlp-spam")
for token in doc:
    print(token.text,",", token.pos_,",", token.tag_,",",spacy.explain(token.tag_))
    
print(doc)
print(spacy.explain('VBZ'))
# Out:
# Apple , PROPN , NNP , noun, proper singular
# is , AUX , VBZ , verb, 3rd person singular present
# looking , VERB , VBG , verb, gerund or present participle
# at , ADP , IN , conjunction, subordinating or preposition
# buying , VERB , VBG , verb, gerund or present participle
# U.K. , PROPN , NNP , noun, proper singular
# startup , NOUN , NN , noun, singular or mass
# for , ADP , IN , conjunction, subordinating or preposition
# $ , SYM , $ , symbol, currency
# 1 , NUM , CD , cardinal number
# billion , NUM , CD , cardinal number
# . , PUNCT , . , punctuation mark, sentence closer
# Apple , PROPN , NNP , noun, proper singular
# is , AUX , VBZ , verb, 3rd person singular present
# very , ADV , RB , adverb
# sweet , ADJ , JJ , adjective
# nlp , ADJ , JJ , adjective
# - , PUNCT , HYPH , punctuation mark, hyphen
# spam , NOUN , NN , noun, singular or mass
# Apple is looking at buying U.K. startup for $1 billion . Apple is very sweet nlp-spam
# verb, 3rd person singular present

# %%
for token in doc:
    print((token.text, token.pos_, token.dep_, spacy.explain(token.dep_)))
# Out:
# ('Apple', 'PROPN', 'nsubj', 'nominal subject')
# ('is', 'AUX', 'aux', 'auxiliary')
# ('looking', 'VERB', 'ROOT', None)
# ('at', 'ADP', 'prep', 'prepositional modifier')
# ('buying', 'VERB', 'pcomp', 'complement of preposition')
# ('U.K.', 'PROPN', 'dobj', 'direct object')
# ('startup', 'NOUN', 'advcl', 'adverbial clause modifier')
# ('for', 'ADP', 'prep', 'prepositional modifier')
# ('$', 'SYM', 'quantmod', 'modifier of quantifier')
# ('1', 'NUM', 'compound', 'compound')
# ('billion', 'NUM', 'pobj', 'object of preposition')
# ('.', 'PUNCT', 'punct', 'punctuation')
# ('Apple', 'PROPN', 'nsubj', 'nominal subject')
# ('is', 'AUX', 'ROOT', None)
# ('very', 'ADV', 'advmod', 'adverbial modifier')
# ('sweet', 'ADJ', 'acomp', 'adjectival complement')
# ('nlp', 'ADJ', 'attr', 'attribute')
# ('-', 'PUNCT', 'punct', 'punctuation')
# ('spam', 'NOUN', 'attr', 'attribute')

# %% [markdown]
# ## Lemmatization , stopwords , shape , dependency etc

# %%
for token in doc:
    print(token.text,":", token.lemma_,":", token.pos_,":", token.tag_,":", token.dep_,":",
            token.shape_,":", token.is_alpha,":", token.is_stop)
    print("\n")
# Out:
# Apple : Apple : PROPN : NNP : nsubj : Xxxxx : True : False
#
#
# is : be : AUX : VBZ : aux : xx : True : True
#
#
# looking : look : VERB : VBG : ROOT : xxxx : True : False
#
#
# at : at : ADP : IN : prep : xx : True : True
#
#
# buying : buy : VERB : VBG : pcomp : xxxx : True : False
#
#
# U.K. : U.K. : PROPN : NNP : dobj : X.X. : False : False
#
#
# startup : startup : NOUN : NN : advcl : xxxx : True : False
#
#
# for : for : ADP : IN : prep : xxx : True : True
#
#
# $ : $ : SYM : $ : quantmod : $ : False : False
#
#
# 1 : 1 : NUM : CD : compound : d : False : False
#
#
# billion : billion : NUM : CD : pobj : xxxx : True : False
#
#
# . : . : PUNCT : . : punct : . : False : False
#
#
# Apple : Apple : PROPN : NNP : nsubj : Xxxxx : True : False
#
#
# is : be : AUX : VBZ : ROOT : xx : True : True
#
#
# very : very : ADV : RB : advmod : xxxx : True : True
#
#
# sweet : sweet : ADJ : JJ : acomp : xxxx : True : False
#
#
# nlp : nlp : ADJ : JJ : attr : xxx : True : False
#
#
# ...

# %%
# viewing dependency-tree
# Note : (interept kernel immediately after running in case of displacy.serve)
import warnings
warnings.filterwarnings('ignore')
from spacy import displacy
doc2 = nlp("Apple is very sweet nlp-spam")
#displacy.serve(doc2, style="dep")
displacy.render(doc2, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="51f364d56659422c826b5e80c3ae168e-0" class="displacy" width="1100" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
# to view dependency-tree in case of large text
doc = nlp("In ancient Rome, some neighbors live in three adjacent houses. In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus. A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom. One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates). One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero. Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin).")
sentence_spans = list(doc.sents)
print(sentence_spans)
displacy.serve(sentence_spans, style="dep")
# Out:
# [In ancient Rome, some neighbors live in three adjacent houses., In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus., A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom., One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates)., One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero., Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin).]
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
# ...

# %% [markdown]
# ## NER
#
# 1. ORG (Companies, agencies, institutions, products.
# 2. GPE (Geopolitical entity, i.e. countries, cities, states.
# 3. MONEY (Monetary values, including unit.

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion . This Pencil runs smoothly at $25 ")
for ent in doc.ents:
    print(ent)
    print(ent.text,":", ent.start_char,":", ent.end_char,":", ent.label_)
# ent.start_char means index of starting in string
# ent.end_char means index of ending in string
# Out:
# Apple
# Apple : 0 : 5 : ORG
# U.K.
# U.K. : 27 : 31 : GPE
# $1 billion
# $1 billion : 44 : 54 : MONEY
# Pencil
# Pencil : 62 : 68 : ORG
# 25
# 25 : 87 : 89 : MONEY

# %%
# Visualizing entity recognizor
displacy.serve(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking at buying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
# ...

# %% [markdown]
# ## Custom sentence detection

# %%
from spacy.language import Language
ellipsis_text = ('Gus, can you, ... never mind, I forgot what I was saying. So, do you think we should ...')

@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    # Adds support to use `...` as the delimiter for sentence detection
    for token in doc[:-1]:
        if token.text == '...':
            doc[token.i+1].is_sent_start = True
    return doc

# Load a new model instance
custom_nlp = spacy.load('en_core_web_sm')
custom_nlp.add_pipe("set_custom_boundaries", before='parser')
custom_ellipsis_doc = custom_nlp(ellipsis_text)
custom_ellipsis_sentences = list(custom_ellipsis_doc.sents)
for sentence in custom_ellipsis_sentences:
     print(sentence)
# Out:
# Gus, can you, ...
# never mind, I forgot what I was saying.
# So, do you think we should ...
# So, do you think we should ...

# %% [markdown]
# ## Some Token methods

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion :-) . This Pencil runs smoothly at $25 ")
for token in doc:
    print(token.text,":", token.prefix,":", token.prefix_,":", token.norm_,":", token.lower_,":",
            token.shape_,":", token.morph ,":", token.is_ascii ,":", token.sentiment )
    print("\n")
# Out:
# Apple : 14862748245026736845 : A : apple : apple : Xxxxx : NounType=Prop|Number=Sing : True : 0.0
#
#
# is : 5097672513440128799 : i : is : is : xx : Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin : True : 0.0
#
#
# looking : 2985121464356781022 : l : looking : looking : xxxx : Aspect=Prog|Tense=Pres|VerbForm=Part : True : 0.0
#
#
# at : 11901859001352538922 : a : at : at : xx :  : True : 0.0
#
#
# buying : 15598372446745583797 : b : buying : buying : xxxx : Aspect=Prog|Tense=Pres|VerbForm=Part : True : 0.0
#
#
# U.K. : 8804677687338025421 : U : u.k. : u.k. : X.X. : NounType=Prop|Number=Sing : True : 0.0
#
#
# startup : 16978132545290669629 : s : startup : startup : xxxx : Number=Sing : True : 0.0
#
#
# for : 13110760720460257827 : f : for : for : xxx :  : True : 0.0
#
#
# $ : 11283501755624150392 : $ : $ : $ : $ :  : True : 0.0
#
#
# 1 : 5533571732986600803 : 1 : 1 : 1 : d : NumType=Card : True : 0.0
#
#
# ...

# %%
var = nlp("I don't like this car it's ugly")
for token in var:
    print(token.text,":", token.sentiment, token.text_with_ws )
# Out:
# I : 0.0 I
# do : 0.0 do
# n't : 0.0 n't
# like : 0.0 like
# this : 0.0 this
# car : 0.0 car
# it : 0.0 it
# 's : 0.0 's
# ugly : 0.0 ugly

# %% [markdown]
# ## Custom tokenization

# %%
about_text = ("Guys he is a great developer in United-States and also in United~Kingdom")
import re
from spacy.tokenizer import Tokenizer
custom_nlp = spacy.load('en_core_web_sm')
prefix_re = spacy.util.compile_prefix_regex(custom_nlp.Defaults.prefixes)
suffix_re = spacy.util.compile_suffix_regex(custom_nlp.Defaults.suffixes)
infix_re = re.compile(r'[-~]') # Tilde and hiphen
def customize_tokenizer(nlp):
     # Adds support to use `-` as the delimiter for tokenization
     return Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
                      suffix_search=suffix_re.search,
                      infix_finditer=infix_re.finditer,
                      token_match=None
                      )


custom_nlp.tokenizer = customize_tokenizer(custom_nlp)
custom_tokenizer_about_doc = custom_nlp(about_text)
print([token.text for token in custom_tokenizer_about_doc])
# Out:
# ['Guys', 'he', 'is', 'a', 'great', 'developer', 'in', 'United', '-', 'States', 'and', 'also', 'in', 'United', '~', 'Kingdom']

# %% [markdown]
# ## Stop Words

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
print(len(spacy_stopwords),'\n')
for i in list(spacy_stopwords)[-10:]:
    print(i)
    
print([token for token in custom_tokenizer_about_doc if token.is_stop == True],'\n')
print([token for token in custom_tokenizer_about_doc if not token.is_stop])
# Out:
# 326
#
# get
# take
# had
# yourself
# whoever
# too
# until
# whereby
# from
# yourselves
# [he, is, a, in, and, also, in]
#
# [Guys, great, developer, United, -, States, United, ~, Kingdom]

# %% [markdown]
# ## Word Frequency

# %%
doc = nlp("In ancient Rome, some neighbors live in three adjacent houses. In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus. A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom. One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates). One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero. Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin).")
from collections import Counter

clean_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
counts = Counter(clean_words)

top_5 = counts.most_common(5)
print(top_5)

all_words = [word for (word , count) in counts.items() if count == int(1)]
all_words
# Out:
# [('Hero', 4), ('Pseudolus', 4), ('ancient', 2), ('houses', 2), ('Senex', 2)]
# ['Rome',
#  'neighbors',
#  'live',
#  'adjacent',
#  'center',
#  'house',
#  'lives',
#  'wife',
#  'son',
#  'slaves',
#  'including',
#  'head',
#  'Hysterium',
#  'musical',
#  'main',
#  'character',
#  'belonging',
#  'wishes',
#  'buy',
#  'win',
#  'steal',
#  'freedom',
#  'neighboring',
#  'owned',
#  'Marcus',
#  'buyer',
#  'seller',
#  'beautiful',
#  'women',
#  'belongs',
#  'Erronius',
#  'abroad',
#  'searching',
#  'long',
#  'lost',
#  'children',
#  'stolen',
#  'infancy',
#  'pirates',
#  'day',
#  'trip',
#  'leave',
#  'charge',
#  'confides',
#  'love',
#  'lovely',
#  'Philia',
#  'courtesans',
#  'House',
#  'albeit',
#  'virgin']

# %%
## Multiple docs
texts = ["This is a text", "These are lots of texts", "..."]
docs = list(nlp.pipe(texts))
print(docs)
for doc in docs:
    print(doc)
# Out:
# [This is a text, These are lots of texts, ...]
# This is a text
# These are lots of texts
# ...
